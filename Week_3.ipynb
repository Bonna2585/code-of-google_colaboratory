# %% [markdown]
# <a href="https://colab.research.google.com/github/b295/code-of-google_colaboratory/blob/master/Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#built-in functions

print("This is Bonna akter")
s=input()

a=35
b=29
print(max(a,b))
print(min(a,b))

c=10.4
d=int(c)
print(d)

e="python"
print(type(e))
# Out:
# This is Bonna akter
# 23
# 35
# 29
# 10
# <class 'str'>

# %%
#user defined function

def add(a, b):
    c=a+b
    return c

a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
d=add(a,b)
print("The sum is", d)
# Out:
# Enter a number: 10
# Enter a number: 20
# The sum is 30

# %%
#function with multiple parameters

def divisor(x,y,m):
    if x%m==0 and y%m==0:
        print("%d & %d are divisible by %d"%(x,y,m))
    elif x%m==0:
        print("only %d is divisible by %d"%(x,m))
    elif y%m==0:
        print("only %d is divisible by %d"%(y,m))
    else:
        print("none of %d & %d is divisible by %d"%(x,y,d))

divisor(10,20,5)
divisor(12,20,5)
divisor(10,22,5)
divisor(2,5,3)
# Out:
# 10 & 20 are divisible by 5
# only 20 is divisible by 5
# only 10 is divisible by 5
# none of 2 & 5 is divisible by 30

# %%
#function without parameter

def summation():
    a=3+8
    return a

b=summation()
print(b)
# Out:
# 11

# %%
#function with default parameter value

def check(a=0):
    if a==0:
        print("Zero")
    elif a>0:
        print("Positive")
    else:
        print("Negative")

check()     #without parameter
check(-4)   #with parameter
# Out:
# Zero
# Negative

# %%
#local scope

def local_scope():
    x=7
    print(x)

local_scope()
# Out:
# 7

# %%
#local scope

def local_scope():
    x=7
    print(x)
    return x

a=local_scope()
print(a)
# Out:
# 7
# 7

# %%
#global scope

x=10

def global_scope():
    print(x)

print(x)
global_scope()
# Out:
# 10
# 10

# %%
#global scope

def global_scope():
    global x
    x=10

global_scope()
print(x)
# Out:
# 10

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#python standard library
#csv module

import csv

with open('gdrive/My Drive/Colab Notebooks/Lab Exercise/data.csv', newline='') as csvfile:
    tmp = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in tmp:
        print(', '.join(row))
# Out:
# "Date","Open","High","Low","Close","Shares, Traded","Turnover, (Rs., Cr)"
# "11-Mar-2020",", , , , 10334.30",", , , , 10545.10",", , , , 10334.00",", , , , 10458.40",", , , , , 1219079693",", , , , , , , , 32548.47"
# "12-Mar-2020",", , , , 10039.95",", , , , 10040.75",", , , , , 9508.00",", , , , , 9590.15",", , , , , 1344263317",", , , , , , , , 39283.97"
# "13-Mar-2020",", , , , , 9107.60",", , , , 10159.40",", , , , , 8555.15",", , , , , 9955.20",", , , , , 1389061775",", , , , , , , , 44167.89"
# "16-Mar-2020",", , , , , 9587.80",", , , , , 9602.20",", , , , , 9165.10",", , , , , 9197.40",", , , , , , 898523271",", , , , , , , , 29181.80"
# "17-Mar-2020",", , , , , 9285.40",", , , , , 9403.80",", , , , , 8915.60",", , , , , 8967.05",", , , , , , 936185892",", , , , , , , , 28004.16"
# "18-Mar-2020",", , , , , 9088.45",", , , , , 9127.55",", , , , , 8407.05",", , , , , 8468.80",", , , , , 1517275761",", , , , , , , , 39256.71"
# ...

# %%
import pandas as panda

# %%
data=panda.read_csv('gdrive/My Drive/Colab Notebooks/Lab Exercise/data.csv')

# %%
data.head(50)
# Out:
#            Date      Open      High  ...     Close  Shares Traded  Turnover (Rs. Cr)
# 0   11-Mar-2020  10334.30  10545.10  ...  10458.40     1219079693           32548.47
# 1   12-Mar-2020  10039.95  10040.75  ...   9590.15     1344263317           39283.97
# 2   13-Mar-2020   9107.60  10159.40  ...   9955.20     1389061775           44167.89
# 3   16-Mar-2020   9587.80   9602.20  ...   9197.40      898523271           29181.80
# 4   17-Mar-2020   9285.40   9403.80  ...   8967.05      936185892           28004.16
# 5   18-Mar-2020   9088.45   9127.55  ...   8468.80     1517275761           39256.71
# 6   19-Mar-2020   8063.30   8575.45  ...   8263.45      926508824           34274.23
# 7   20-Mar-2020   8284.45   8883.00  ...   8745.45     1072263600           37321.25
# 8   23-Mar-2020   7945.70   8159.25  ...   7610.25      654151814           23891.90
# 9   24-Mar-2020   7848.30   8036.95  ...   7801.05      739354439           28282.09
# ...

# %%
data.tail(50)
# Out:
#             Date      Open  ...  Shares Traded  Turnover (Rs. Cr)
# 100  06-Aug-2020  11185.70  ...      600374615           31501.08
# 101  07-Aug-2020  11186.65  ...      452629891           27054.43
# 102  10-Aug-2020  11270.25  ...      491999534           29108.25
# 103  11-Aug-2020  11322.25  ...      586084846           30314.89
# 104  12-Aug-2020  11289.00  ...      609858960           28088.09
# 105  13-Aug-2020  11334.85  ...      562355175           26500.52
# 106  14-Aug-2020  11353.30  ...      645109756           31059.23
# 107  17-Aug-2020  11248.90  ...      633963958           27468.67
# 108  18-Aug-2020  11259.80  ...      579242492           27267.51
# 109  19-Aug-2020  11452.15  ...      626217997           27528.12
# 110  20-Aug-2020  11317.45  ...      791587770           27676.18
# 111  21-Aug-2020  11409.65  ...      668719170           26294.26
# 112  24-Aug-2020  11412.00  ...      532900535           28920.84
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               150 non-null    object
#  1   Open               150 non-null    float64
#  2   High               150 non-null    float64
#  3   Low                150 non-null    float64
#  4   Close              150 non-null    float64
#  5   Shares Traded      150 non-null    int64
#  6   Turnover (Rs. Cr)  150 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.3+ KB

# %%
data.shape
# Out:
# (150, 7)

# %%
#python standard library
#math module

import math

print(math.pi)          #value of pi

x=9.2
print(math.ceil(x))     #round to the smallest integer not less than x
print(math.floor(x))    #rount to the largest integer not greater than x

print(math.sin(88))     #trigonometric sine of x (x in radians)

print(math.pow(2,3))    #2 to the power 3

print(math.sqrt(26))    #square root of 16
# Out:
# 3.141592653589793
# 10
# 9
# 0.03539830273366068
# 8.0
# 5.0990195135927845
